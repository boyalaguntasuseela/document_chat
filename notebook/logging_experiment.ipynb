# %%
import os
import logging
from datetime import datetime

# %%
print("hi")

# %%
os.getcwd()
os.path.join(os.getcwd(), "logs")
os.makedirs(os.path.join(os.getcwd(), "logs"))

# %%
datetime.now()
# Out:
# datetime.datetime(2026, 5, 18, 11, 39, 7, 681934)

# %%
Log_File = f"{datetime.now().strftime('%m_%d_%y0')}.logs"
print(Log_File)
# Out:
# 05_18_260.logs

# %%
Log_Folder = os.path.join(os.getcwd(), "logs")
print(os.path.join(Log_Folder,Log_File ))
Log_File_Path = os.path.join(Log_Folder,Log_File)
# Out:
# d:\SHIVA _CLASS\RAG_PROJECT\document_chat\notebook\logs\05_18_260.logs

# %%
logging.basicConfig(
    filename = Log_File_Path,
    format = "[%(asctime)s ] %(levelname)s %(name)s (line: %(lineno)d) - %(message)s",
    level=logging.INFO  )

# %%
logger = logging .getLogger(__name__)
logger.info("I set up python logging")
